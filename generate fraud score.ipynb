# %%
import numpy as np
import pandas as pd
import networkx as nx
import pathlib
import sklearn
import time

from networkx.algorithms import bipartite
from networkx.algorithms.centrality import degree_centrality, subgraph_centrality
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '1.0.5'

# %%
import bokeh
from bokeh.io import output_file, show
from bokeh.models import (BoxZoomTool, Circle, HoverTool, Scatter, 
                          MultiLine, Plot, Range1d, ResetTool, 
                          ColumnDataSource, CustomJSTransform, LabelSet)
from bokeh.palettes import Spectral4, RdYlGn4
from bokeh.plotting import figure
from bokeh.transform import linear_cmap, factor_mark
from bokeh.models.graphs import from_networkx

bokeh.__version__
# Out:
# '2.1.1'

# %%
from pathlib import Path
Path.cwd()
# Out:
# PosixPath('/Users/dawnstaana/Documents/NUS/Year 4/NUS Fintech/Insurance')

# %%
from utils import (Bipartite, calculate_birank, 
preprocess, preprocess_new_claim, 
calculate_new_claim, get_subgraph, 
get_subgraph_regular, get_claim_features, get_fraud_features, make_graph)

# %%
data = pd.read_csv("df.csv", header=0, parse_dates=["LOSS_DATE"], infer_datetime_format=True).drop_duplicates()
data.head()
# Out:
#    months_as_customer  age         CUST_CODE policy_bind_date policy_state  \
# 0                 328   48  customer_ 521585         17/10/14           OH
# 1                 228   42  customer_ 342868          27/6/06           IN
# 2                 134   29  customer_ 687698           9/6/00           OH
# 3                 256   41  customer_ 227811          25/5/90           IL
# 4                 228   44  customer_ 367455           6/6/14           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ...  auto_make auto_model auto_year fraud_flag  \
# 0       466132  ...       Saab        92x      2004          1
# 1       468176  ...   Mercedes       E400      2007          1
# 2       430632  ...      Dodge        RAM      2007          0
# 3       608117  ...  Chevrolet      Tahoe      2014          1
# 4       610706  ...     Accura        RSX      2009          0
#
#   age_car_incident  age_policy_incident  WORKSHOP_ID   CLAIM_HANDLER  \
# 0               11                    1  workshop_ A  handler_ Frank
# 1                8                    9  workshop_ A  handler_ Frank
# 2                8                   15  workshop_ A  handler_ Frank
# 3                1                   25  workshop_ C  handler_ Harry
# 4                6                    1  workshop_ C  handler_ Harry
#
#    CLAIM_NO investigation_flag
# 0  claim_ 1                  1
# 1  claim_ 2                  1
# 2  claim_ 3                  0
# 3  claim_ 4                  1
# 4  claim_ 5                  0
#
# [5 rows x 45 columns]

# %%
relevant_cols = ["CLAIM_NO", "CUST_CODE", "CLAIM_HANDLER", "WORKSHOP_ID", "investigation_flag", "fraud_flag"]
df = data[relevant_cols]
df.head()
print(df.shape)
#test_claim_dict = {
    #'CLAIM_NO': ['claim_ 12345678'],
    #'CUST_CODE': ['customer_ 118333'],
    #'CLAIM_HANDLER': ['handler_ Harry'],
    #'WORKSHOP_ID': ['workshop_ 247'],
    #'investigation_flag': 1,
    #'fraud_flag': 1
#}
#test_claim = pd.DataFrame(test_claim_dict)
#test_claim
# Out:
# (1000, 6)

# %%
claims_df = df.copy()
#df = pd.concat([df, test_claim], axis=0).reset_index(drop=True)
print(df.shape)
df.tail()
# Out:
# (1000, 6)
#         CLAIM_NO         CUST_CODE   CLAIM_HANDLER  WORKSHOP_ID  \
# 995   claim_ 996  customer_ 941851   handler_ Jeff  workshop_ E
# 996   claim_ 997  customer_ 186934   handler_ Jeff  workshop_ E
# 997   claim_ 998  customer_ 918516  handler_ Frank  workshop_ A
# 998   claim_ 999  customer_ 533940  handler_ Frank  workshop_ A
# 999  claim_ 1000  customer_ 556080  handler_ Frank  workshop_ A
#
#      investigation_flag  fraud_flag
# 995                   0           0
# 996                   0           0
# 997                   0           0
# 998                   0           0
# 999                   0           0

# %%
policyholder_edgelist = df[['CLAIM_NO', 'CUST_CODE']].rename(columns={'CLAIM_NO':'Claims', 'CUST_CODE':'Parties'}).dropna()
expert_edgelist = df[['CLAIM_NO', 'CLAIM_HANDLER']].rename(columns={'CLAIM_NO':'Claims', 'CLAIM_HANDLER':'Parties'}).dropna()
garage_edgelist = df[['CLAIM_NO', 'WORKSHOP_ID']].rename(columns={'CLAIM_NO':'Claims', 'WORKSHOP_ID':'Parties'}).dropna()
edgelist_df = pd.concat([policyholder_edgelist, expert_edgelist, garage_edgelist], axis=0).sort_values(by='Claims').reset_index(drop=True)
edgelist_df = edgelist_df[['Parties', 'Claims']]
print(edgelist_df.shape)
# Out:
# (3000, 2)

# %%
policyholder_edgelist
# Out:
#           Claims           Parties
# 0       claim_ 1  customer_ 521585
# 1       claim_ 2  customer_ 342868
# 2       claim_ 3  customer_ 687698
# 3       claim_ 4  customer_ 227811
# 4       claim_ 5  customer_ 367455
# ..           ...               ...
# 995   claim_ 996  customer_ 941851
# 996   claim_ 997  customer_ 186934
# 997   claim_ 998  customer_ 918516
# 998   claim_ 999  customer_ 533940
# 999  claim_ 1000  customer_ 556080
#
# [1000 rows x 2 columns]

# %%
edgelist_df
# Out:
#                Parties      Claims
# 0     customer_ 521585    claim_ 1
# 1          workshop_ A    claim_ 1
# 2       handler_ Frank    claim_ 1
# 3          workshop_ D   claim_ 10
# 4        handler_ Ivan   claim_ 10
# ...                ...         ...
# 2995  customer_ 918516  claim_ 998
# 2996       workshop_ A  claim_ 998
# 2997       workshop_ A  claim_ 999
# 2998  customer_ 533940  claim_ 999
# 2999    handler_ Frank  claim_ 999
#
# [3000 rows x 2 columns]

# %%
mask = df['fraud_flag'] == 1
prior = df[mask]['CLAIM_NO'].values
prior
# Out:
# array(['claim_ 1', 'claim_ 2', 'claim_ 4', 'claim_ 6', 'claim_ 15',
#        'claim_ 16', 'claim_ 23', 'claim_ 24', 'claim_ 26', 'claim_ 28',
#        'claim_ 32', 'claim_ 36', 'claim_ 37', 'claim_ 40', 'claim_ 42',
#        'claim_ 48', 'claim_ 61', 'claim_ 64', 'claim_ 65', 'claim_ 66',
#        'claim_ 67', 'claim_ 71', 'claim_ 72', 'claim_ 80', 'claim_ 85',
#        'claim_ 90', 'claim_ 92', 'claim_ 97', 'claim_ 98', 'claim_ 107',
#        'claim_ 109', 'claim_ 110', 'claim_ 112', 'claim_ 116',
#        'claim_ 118', 'claim_ 122', 'claim_ 123', 'claim_ 129',
#        'claim_ 130', 'claim_ 136', 'claim_ 144', 'claim_ 146',
#        'claim_ 147', 'claim_ 149', 'claim_ 150', 'claim_ 153',
#        'claim_ 155', 'claim_ 156', 'claim_ 164', 'claim_ 167',
#        'claim_ 172', 'claim_ 184', 'claim_ 186', 'claim_ 189',
#        'claim_ 197', 'claim_ 207', 'claim_ 214', 'claim_ 215',
#        'claim_ 216', 'claim_ 219', 'claim_ 221', 'claim_ 228',
#        'claim_ 235', 'claim_ 238', 'claim_ 242', 'claim_ 246',
#        'claim_ 248', 'claim_ 251', 'claim_ 252', 'claim_ 254',
#        'claim_ 255', 'claim_ 258', 'claim_ 260', 'claim_ 262',
#        'claim_ 263', 'claim_ 267', 'claim_ 273', 'claim_ 278',
#        'claim_ 279', 'claim_ 282', 'claim_ 284', 'claim_ 289',
#        'claim_ 293', 'claim_ 295', 'claim_ 306', 'claim_ 307',
#        'claim_ 308', 'claim_ 311', 'claim_ 312', 'claim_ 320',
#        'claim_ 325', 'claim_ 329', 'claim_ 330', 'claim_ 332',
#        'claim_ 341', 'claim_ 343', 'claim_ 345', 'claim_ 350',
#        'claim_ 352', 'claim_ 359', 'claim_ 361', 'claim_ 362',
#        'claim_ 364', 'claim_ 365', 'claim_ 366', 'claim_ 369',
#        'claim_ 374', 'claim_ 380', 'claim_ 383', 'claim_ 384',
#        'claim_ 395', 'claim_ 403', 'claim_ 405', 'claim_ 425',
#        'claim_ 426', 'claim_ 429', 'claim_ 433', 'claim_ 438',
#        'claim_ 443', 'claim_ 446', 'claim_ 458', 'claim_ 461',
#        'claim_ 463', 'claim_ 471', 'claim_ 475', 'claim_ 477',
#        'claim_ 478', 'claim_ 479', 'claim_ 480', 'claim_ 483',
#        'claim_ 490', 'claim_ 495', 'claim_ 499', 'claim_ 505',
#        'claim_ 514', 'claim_ 518', 'claim_ 530', 'claim_ 536',
#        'claim_ 539', 'claim_ 545', 'claim_ 548', 'claim_ 553',
#        'claim_ 556', 'claim_ 559', 'claim_ 562', 'claim_ 568',
#        'claim_ 574', 'claim_ 575', 'claim_ 578', 'claim_ 580',
#        'claim_ 588', 'claim_ 592', 'claim_ 594', 'claim_ 598',
#        'claim_ 601', 'claim_ 603', 'claim_ 617', 'claim_ 621',
#        'claim_ 624', 'claim_ 629', 'claim_ 630', 'claim_ 634',
#        'claim_ 636', 'claim_ 639', 'claim_ 644', 'claim_ 650',
#        'claim_ 651', 'claim_ 653', 'claim_ 658', 'claim_ 666',
#        'claim_ 667', 'claim_ 684', 'claim_ 685', 'claim_ 692',
#        'claim_ 700', 'claim_ 701', 'claim_ 702', 'claim_ 704',
#        'claim_ 705', 'claim_ 706', 'claim_ 708', 'claim_ 709',
#        'claim_ 710', 'claim_ 711', 'claim_ 713', 'claim_ 714',
#        'claim_ 716', 'claim_ 723', 'claim_ 728', 'claim_ 729',
#        'claim_ 730', 'claim_ 743', 'claim_ 744', 'claim_ 745',
#        'claim_ 746', 'claim_ 762', 'claim_ 763', 'claim_ 764',
#        'claim_ 785', 'claim_ 786', 'claim_ 789', 'claim_ 792',
#        'claim_ 797', 'claim_ 804', 'claim_ 810', 'claim_ 813',
#        'claim_ 818', 'claim_ 824', 'claim_ 830', 'claim_ 832',
#        'claim_ 838', 'claim_ 839', 'claim_ 844', 'claim_ 846',
#        'claim_ 849', 'claim_ 852', 'claim_ 866', 'claim_ 869',
#        'claim_ 870', 'claim_ 873', 'claim_ 876', 'claim_ 879',
#        'claim_ 881', 'claim_ 882', 'claim_ 884', 'claim_ 896',
#        'claim_ 906', 'claim_ 913', 'claim_ 916', 'claim_ 920',
#        'claim_ 927', 'claim_ 928', 'claim_ 930', 'claim_ 931',
#        'claim_ 936', 'claim_ 939', 'claim_ 940', 'claim_ 947',
#        'claim_ 965', 'claim_ 968', 'claim_ 973', 'claim_ 974',
#        'claim_ 975', 'claim_ 978', 'claim_ 983', 'claim_ 987',
#        'claim_ 988'], dtype=object)

# %%
birank_df = calculate_birank(edgelist_df, prior)
print(birank_df.shape)
birank_df.tail()
# Out:
# No. of known prior fraudulent flags: 247.0 Length of prior_vector: 1000
# (2010, 3)
#             node  birank_score  birank_scaled
# 2005  claim_ 995      0.207558       0.032304
# 2006  claim_ 996      0.149816       0.016896
# 2007  claim_ 997      0.149816       0.016896
# 2008  claim_ 998      0.207558       0.032304
# 2009  claim_ 999      0.207558       0.032304

# %%
G, claims_attr, parties_attr = preprocess(claims_df, birank_df)
# Out:
# Name:
# Type: Graph
# Number of nodes: 2010
# Number of edges: 3000
# Average degree:   2.9851
# Graph is bipartite:  True

# %%
new_claim_dict = {
    'CLAIM_NO': ['claim_ 1234567'],
    'CUST_CODE': ['customer_ 773651'],
    'CLAIM_HANDLER': ['handler_ Harry'],
    'WORKSHOP_ID': ['workshop_ A']
}
new_claim = pd.DataFrame(new_claim_dict)
new_claim
# Out:
#          CLAIM_NO         CUST_CODE   CLAIM_HANDLER  WORKSHOP_ID
# 0  claim_ 1234567  customer_ 773651  handler_ Harry  workshop_ A

# %%
edgelist_df_with_new_claim, new_claim_edgelist_df = preprocess_new_claim(new_claim, G)
# Out:
# Name:
# Type: Graph
# Number of nodes: 2012
# Number of edges: 3003
# Average degree:   2.9851
# Graph Bipartite:  True

# %%
new_birank, new_df, birank_df, new_parties_attr, new_claims_attr = calculate_new_claim(claims_df, new_claim, edgelist_df_with_new_claim, new_claim_edgelist_df, parties_attr, claims_attr, prior)
# Out:
# No. of known prior fraudulent flags: 247.0 Length of prior_vector: 1001

# %%
G.nodes['claim_ 1234567']
# Out:
# {'bipartite': 1}

# %%
nx.set_node_attributes(G, new_claims_attr)
nx.set_node_attributes(G, new_parties_attr)

# %%
test_threshold = birank_df['birank_score'].quantile(0.995)
test_threshold
# Out:
# 0.4181531773467503

# %%
subgraph_nodes, subgraph_edges = get_subgraph(new_claim, new_birank, new_claim_edgelist_df, new_df, birank_df, prior)
regular_nodes, regular_edges = get_subgraph_regular(new_birank, new_df, birank_df, test_threshold, prior)

# %%
subgraph = nx.Graph()
subgraph.add_nodes_from(subgraph_nodes)
subgraph.add_edges_from(subgraph_edges)
subgraph.add_nodes_from(regular_nodes)
subgraph.add_edges_from(regular_edges)
nx.set_node_attributes(subgraph, new_parties_attr)
nx.set_node_attributes(subgraph, new_claims_attr)
print(nx.info(subgraph))
# Out:
# Name:
# Type: Graph
# Number of nodes: 193
# Number of edges: 192
# Average degree:   1.9896

# %%
make_graph(subgraph, new_birank)
# Out:
# BokehDeprecationWarning: Importing from_networkx from bokeh.models.graphs is deprecated and will be removed in Bokeh 3.0. Import from bokeh.plotting instead

# %%
from cookbook import (get_edgeweight, Bipartite,generate_n1_q1,generate_n1_med,generate_n1_max,generate_n2_q1,
                      generate_n2_med,generate_n2_max,generate_n1_size,generate_n2_size,generate_n2_ratioFraud,
                      generate_n2_ratioNonFraud,generate_n2_binFraud)

# %%
G.add_nodes_from(claims_attr)

# %%
G.add_nodes_from(parties_attr)

# %%
claims_attr
# Out:
# {'claim_ 1': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 2': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 3': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 4': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 5': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 6': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 7': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 8': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 9': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 10': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 11': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 12': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 13': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 14': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 15': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 16': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 17': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 18': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 19': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 20': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 21': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 22': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 23': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 24': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 25': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 26': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 27': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 28': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 29': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 30': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 31': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 32': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 33': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 34': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 35': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 36': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 37': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 38': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 39': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 40': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 41': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 42': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 43': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 44': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 45': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 46': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 47': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 48': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 49': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 50': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 51': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 52': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 53': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 54': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 55': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 56': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 57': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 58': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 59': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 60': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 61': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 62': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 63': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 64': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 65': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 66': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 67': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 68': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 69': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 70': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 71': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 72': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 73': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 74': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 75': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 76': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 77': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 78': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 79': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 80': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 81': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 82': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 83': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 84': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 85': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 86': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 87': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 88': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 89': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 90': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 91': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 92': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 93': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 94': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 95': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 96': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 97': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 98': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 99': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 100': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 101': {'fraudulent': 0,
#   'birank_score': 0.2101853573612996,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 102': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 103': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 104': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 105': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 106': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 107': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 108': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 109': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 110': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 111': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 112': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 113': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 114': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 115': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 116': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 117': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 118': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 119': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 120': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 121': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 122': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 123': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 124': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 125': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 126': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 127': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 128': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 129': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 130': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 131': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 132': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 133': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 134': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 135': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 136': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 137': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 138': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 139': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 140': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 141': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 142': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 143': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 144': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 145': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 146': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 147': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 148': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 149': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 150': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 151': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 152': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 153': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 154': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 155': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 156': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 157': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 158': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 159': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 160': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 161': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 162': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 163': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 164': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 165': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 166': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 167': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 168': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 169': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 170': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 171': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 172': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 173': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 174': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 175': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 176': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 177': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 178': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 179': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 180': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 181': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 182': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 183': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 184': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 185': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 186': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 187': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 188': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 189': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 190': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 191': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 192': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 193': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 194': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 195': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 196': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 197': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 198': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 199': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 200': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 201': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 202': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 203': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 204': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 205': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 206': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 207': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 208': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 209': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 210': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 211': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 212': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 213': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 214': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 215': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 216': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 217': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 218': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 219': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 220': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 221': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 222': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 223': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 224': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 225': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 226': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 227': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 228': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 229': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 230': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 231': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 232': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 233': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 234': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 235': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 236': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 237': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 238': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 239': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 240': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 241': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 242': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 243': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 244': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 245': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 246': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 247': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 248': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 249': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 250': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 251': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 252': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 253': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 254': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 255': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 256': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 257': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 258': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 259': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 260': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 261': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 262': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 263': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 264': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 265': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 266': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 267': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 268': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 269': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 270': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 271': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 272': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 273': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 274': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 275': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 276': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 277': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 278': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 279': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 280': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 281': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 282': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 283': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 284': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 285': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 286': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 287': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 288': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 289': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 290': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 291': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 292': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 293': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 294': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 295': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 296': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 297': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 298': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 299': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 300': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 301': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 302': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 303': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 304': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 305': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 306': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 307': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 308': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 309': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 310': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 311': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 312': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 313': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 314': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 315': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 316': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 317': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 318': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 319': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 320': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 321': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 322': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 323': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 324': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 325': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 326': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 327': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 328': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 329': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 330': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 331': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 332': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 333': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 334': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 335': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 336': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 337': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 338': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 339': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 340': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 341': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 342': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 343': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 344': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 345': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 346': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 347': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 348': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 349': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 350': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 351': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 352': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 353': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 354': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 355': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 356': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 357': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 358': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 359': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 360': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 361': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 362': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 363': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 364': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 365': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 366': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 367': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 368': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 369': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 370': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 371': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 372': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 373': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 374': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 375': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 376': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 377': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 378': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 379': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 380': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 381': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 382': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 383': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 384': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 385': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 386': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 387': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 388': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 389': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 390': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 391': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 392': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 393': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 394': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 395': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 396': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 397': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 398': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 399': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 400': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 401': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 402': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 403': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 404': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 405': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 406': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 407': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 408': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 409': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 410': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 411': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 412': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 413': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 414': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 415': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 416': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 417': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 418': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 419': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 420': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 421': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 422': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 423': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 424': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 425': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 426': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 427': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 428': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 429': {'fraudulent': 1,
# ...
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 859': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 860': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 861': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 862': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 863': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 864': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 865': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 866': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 867': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 868': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 869': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 870': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 871': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 872': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 873': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 874': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 875': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 876': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 877': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 878': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 879': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 880': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 881': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 882': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 883': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 884': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 885': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 886': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 887': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 888': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 889': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 890': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 891': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 892': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 893': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 894': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 895': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 896': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 897': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 898': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 899': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 900': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 901': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 902': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 903': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 904': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 905': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 906': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 907': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 908': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 909': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 910': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 911': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 912': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 913': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 914': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 915': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 916': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 917': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 918': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 919': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 920': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 921': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 922': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 923': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 924': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 925': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 926': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 927': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 928': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 929': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 930': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 931': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 932': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 933': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 934': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 935': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 936': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 937': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 938': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 939': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 940': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 941': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 942': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 943': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 944': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 945': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 946': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 947': {'fraudulent': 1,
#   'birank_score': 0.35911865549005073,
#   'birank': 0.07275,
#   'type': 'Claim'},
#  'claim_ 948': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 949': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 950': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 951': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 952': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 953': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 954': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 955': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 956': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 957': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 958': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 959': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 960': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 961': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 962': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 963': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 964': {'fraudulent': 0,
#   'birank_score': 0.21018535736129956,
#   'birank': 0.03301,
#   'type': 'Claim'},
#  'claim_ 965': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 966': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 967': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 968': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 969': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 970': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 971': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 972': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 973': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 974': {'fraudulent': 1,
#   'birank_score': 0.41948768294269495,
#   'birank': 0.08886,
#   'type': 'Claim'},
#  'claim_ 975': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 976': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 977': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 978': {'fraudulent': 1,
#   'birank_score': 0.40237957245979805,
#   'birank': 0.08429,
#   'type': 'Claim'},
#  'claim_ 979': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 980': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 981': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 982': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 983': {'fraudulent': 1,
#   'birank_score': 0.3595348119620194,
#   'birank': 0.07286,
#   'type': 'Claim'},
#  'claim_ 984': {'fraudulent': 0,
#   'birank_score': 0.19307724687840264,
#   'birank': 0.02844,
#   'type': 'Claim'},
#  'claim_ 985': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 986': {'fraudulent': 0,
#   'birank_score': 0.15023248638062403,
#   'birank': 0.01701,
#   'type': 'Claim'},
#  'claim_ 987': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 988': {'fraudulent': 1,
#   'birank_score': 0.4168603659756818,
#   'birank': 0.08815,
#   'type': 'Claim'},
#  'claim_ 989': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 990': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 991': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 992': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 993': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 994': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 995': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 996': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 997': {'fraudulent': 0,
#   'birank_score': 0.14981632990865534,
#   'birank': 0.0169,
#   'type': 'Claim'},
#  'claim_ 998': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 999': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'},
#  'claim_ 1000': {'fraudulent': 0,
#   'birank_score': 0.20755804039428644,
#   'birank': 0.0323,
#   'type': 'Claim'}}

# %%
import numpy as np
import pandas as pd
import networkx as nx
import sklearn
import scipy
import scipy.sparse as spa
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
# %matplotlib inline
np.set_printoptions(precision=3)
np.set_printoptions(threshold=999)

# %%
birank_df['node']
# Out:
# 0       customer_ 100804
# 1       customer_ 101421
# 2       customer_ 104594
# 3       customer_ 106186
# 4       customer_ 106873
#               ...
# 2007          claim_ 606
# 2008          claim_ 559
# 2009          claim_ 674
# 2010          claim_ 383
# 2011      claim_ 1234567
# Name: node, Length: 2012, dtype: object

# %%
epo = [u + (1,) for u in G.edges]

# %%
G.add_weighted_edges_from(epo)

# %%
for u, v, d in G.edges(data=True):
    d['weight'] = d['weight'] / np.sqrt(G.degree[u] * G.degree[v])
    print( (u, G.degree[u], v, G.degree[v]), d)
# Out:
# ('claim_ 1', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 1', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 1', 3, 'customer_ 521585', 1) {'weight': 0.5773502691896258}
# ('claim_ 2', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 2', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 2', 3, 'customer_ 342868', 1) {'weight': 0.5773502691896258}
# ('claim_ 3', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 3', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 3', 3, 'customer_ 687698', 1) {'weight': 0.5773502691896258}
# ('claim_ 4', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 4', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 4', 3, 'customer_ 227811', 1) {'weight': 0.5773502691896258}
# ('claim_ 5', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 5', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 5', 3, 'customer_ 367455', 1) {'weight': 0.5773502691896258}
# ('claim_ 6', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 6', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 6', 3, 'customer_ 104594', 1) {'weight': 0.5773502691896258}
# ('claim_ 7', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 7', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 7', 3, 'customer_ 413978', 1) {'weight': 0.5773502691896258}
# ('claim_ 8', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 8', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 8', 3, 'customer_ 429027', 1) {'weight': 0.5773502691896258}
# ('claim_ 9', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 9', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 9', 3, 'customer_ 485665', 1) {'weight': 0.5773502691896258}
# ('claim_ 10', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 10', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 10', 3, 'customer_ 636550', 1) {'weight': 0.5773502691896258}
# ('claim_ 11', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 11', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 11', 3, 'customer_ 543610', 1) {'weight': 0.5773502691896258}
# ('claim_ 12', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 12', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 12', 3, 'customer_ 214618', 1) {'weight': 0.5773502691896258}
# ('claim_ 13', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 13', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 13', 3, 'customer_ 842643', 1) {'weight': 0.5773502691896258}
# ('claim_ 14', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 14', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 14', 3, 'customer_ 626808', 1) {'weight': 0.5773502691896258}
# ('claim_ 15', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 15', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 15', 3, 'customer_ 644081', 1) {'weight': 0.5773502691896258}
# ('claim_ 16', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 16', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 16', 3, 'customer_ 892874', 1) {'weight': 0.5773502691896258}
# ('claim_ 17', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 17', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 17', 3, 'customer_ 558938', 1) {'weight': 0.5773502691896258}
# ('claim_ 18', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 18', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 18', 3, 'customer_ 275265', 1) {'weight': 0.5773502691896258}
# ('claim_ 19', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 19', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 19', 3, 'customer_ 921202', 1) {'weight': 0.5773502691896258}
# ('claim_ 20', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 20', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 20', 3, 'customer_ 143972', 1) {'weight': 0.5773502691896258}
# ('claim_ 21', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 21', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 21', 3, 'customer_ 183430', 1) {'weight': 0.5773502691896258}
# ('claim_ 22', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 22', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 22', 3, 'customer_ 431876', 1) {'weight': 0.5773502691896258}
# ('claim_ 23', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 23', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 23', 3, 'customer_ 285496', 1) {'weight': 0.5773502691896258}
# ('claim_ 24', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 24', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 24', 3, 'customer_ 115399', 1) {'weight': 0.5773502691896258}
# ('claim_ 25', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 25', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 25', 3, 'customer_ 736882', 1) {'weight': 0.5773502691896258}
# ('claim_ 26', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 26', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 26', 3, 'customer_ 699044', 1) {'weight': 0.5773502691896258}
# ('claim_ 27', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 27', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 27', 3, 'customer_ 863236', 1) {'weight': 0.5773502691896258}
# ('claim_ 28', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 28', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 28', 3, 'customer_ 608513', 1) {'weight': 0.5773502691896258}
# ('claim_ 29', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 29', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 29', 3, 'customer_ 914088', 1) {'weight': 0.5773502691896258}
# ('claim_ 30', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 30', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 30', 3, 'customer_ 596785', 1) {'weight': 0.5773502691896258}
# ('claim_ 31', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 31', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 31', 3, 'customer_ 908616', 1) {'weight': 0.5773502691896258}
# ('claim_ 32', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 32', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 32', 3, 'customer_ 666333', 1) {'weight': 0.5773502691896258}
# ('claim_ 33', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 33', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 33', 3, 'customer_ 336614', 1) {'weight': 0.5773502691896258}
# ('claim_ 34', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 34', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 34', 3, 'customer_ 584859', 1) {'weight': 0.5773502691896258}
# ('claim_ 35', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 35', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 35', 3, 'customer_ 990493', 1) {'weight': 0.5773502691896258}
# ('claim_ 36', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 36', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 36', 3, 'customer_ 129872', 1) {'weight': 0.5773502691896258}
# ('claim_ 37', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 37', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 37', 3, 'customer_ 200152', 1) {'weight': 0.5773502691896258}
# ('claim_ 38', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 38', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 38', 3, 'customer_ 933293', 1) {'weight': 0.5773502691896258}
# ('claim_ 39', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 39', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 39', 3, 'customer_ 485664', 1) {'weight': 0.5773502691896258}
# ('claim_ 40', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 40', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 40', 3, 'customer_ 982871', 1) {'weight': 0.5773502691896258}
# ('claim_ 41', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 41', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 41', 3, 'customer_ 206213', 1) {'weight': 0.5773502691896258}
# ('claim_ 42', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 42', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 42', 3, 'customer_ 616337', 1) {'weight': 0.5773502691896258}
# ('claim_ 43', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 43', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 43', 3, 'customer_ 448961', 1) {'weight': 0.5773502691896258}
# ('claim_ 44', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 44', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 44', 3, 'customer_ 790442', 1) {'weight': 0.5773502691896258}
# ('claim_ 45', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 45', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 45', 3, 'customer_ 108844', 1) {'weight': 0.5773502691896258}
# ('claim_ 46', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 46', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 46', 3, 'customer_ 430029', 1) {'weight': 0.5773502691896258}
# ('claim_ 47', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 47', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 47', 3, 'customer_ 529112', 1) {'weight': 0.5773502691896258}
# ('claim_ 48', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 48', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 48', 3, 'customer_ 939631', 1) {'weight': 0.5773502691896258}
# ('claim_ 49', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 49', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 49', 3, 'customer_ 866931', 1) {'weight': 0.5773502691896258}
# ('claim_ 50', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 50', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 50', 3, 'customer_ 582011', 1) {'weight': 0.5773502691896258}
# ('claim_ 51', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 51', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 51', 3, 'customer_ 691189', 1) {'weight': 0.5773502691896258}
# ('claim_ 52', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 52', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 52', 3, 'customer_ 537546', 1) {'weight': 0.5773502691896258}
# ('claim_ 53', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 53', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 53', 3, 'customer_ 394975', 1) {'weight': 0.5773502691896258}
# ('claim_ 54', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 54', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 54', 3, 'customer_ 729634', 1) {'weight': 0.5773502691896258}
# ('claim_ 55', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 55', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 55', 3, 'customer_ 282195', 1) {'weight': 0.5773502691896258}
# ('claim_ 56', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 56', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 56', 3, 'customer_ 420810', 1) {'weight': 0.5773502691896258}
# ('claim_ 57', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 57', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 57', 3, 'customer_ 524836', 1) {'weight': 0.5773502691896258}
# ('claim_ 58', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 58', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 58', 3, 'customer_ 307195', 1) {'weight': 0.5773502691896258}
# ('claim_ 59', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 59', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 59', 3, 'customer_ 623648', 1) {'weight': 0.5773502691896258}
# ('claim_ 60', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 60', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 60', 3, 'customer_ 485372', 1) {'weight': 0.5773502691896258}
# ('claim_ 61', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 61', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 61', 3, 'customer_ 598554', 1) {'weight': 0.5773502691896258}
# ('claim_ 62', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 62', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 62', 3, 'customer_ 303987', 1) {'weight': 0.5773502691896258}
# ('claim_ 63', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 63', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 63', 3, 'customer_ 343161', 1) {'weight': 0.5773502691896258}
# ('claim_ 64', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 64', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 64', 3, 'customer_ 519312', 1) {'weight': 0.5773502691896258}
# ('claim_ 65', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 65', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 65', 3, 'customer_ 132902', 1) {'weight': 0.5773502691896258}
# ('claim_ 66', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 66', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 66', 3, 'customer_ 332867', 1) {'weight': 0.5773502691896258}
# ('claim_ 67', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 67', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 67', 3, 'customer_ 356590', 1) {'weight': 0.5773502691896258}
# ('claim_ 68', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 68', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 68', 3, 'customer_ 346002', 1) {'weight': 0.5773502691896258}
# ('claim_ 69', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 69', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 69', 3, 'customer_ 500533', 1) {'weight': 0.5773502691896258}
# ('claim_ 70', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 70', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 70', 3, 'customer_ 348209', 1) {'weight': 0.5773502691896258}
# ('claim_ 71', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 71', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 71', 3, 'customer_ 486676', 1) {'weight': 0.5773502691896258}
# ('claim_ 72', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 72', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 72', 3, 'customer_ 260845', 1) {'weight': 0.5773502691896258}
# ('claim_ 73', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 73', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 73', 3, 'customer_ 657045', 1) {'weight': 0.5773502691896258}
# ('claim_ 74', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 74', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 74', 3, 'customer_ 761189', 1) {'weight': 0.5773502691896258}
# ('claim_ 75', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 75', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 75', 3, 'customer_ 175177', 1) {'weight': 0.5773502691896258}
# ('claim_ 76', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 76', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 76', 3, 'customer_ 116700', 1) {'weight': 0.5773502691896258}
# ('claim_ 77', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 77', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 77', 3, 'customer_ 166264', 1) {'weight': 0.5773502691896258}
# ('claim_ 78', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 78', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 78', 3, 'customer_ 527945', 1) {'weight': 0.5773502691896258}
# ('claim_ 79', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 79', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 79', 3, 'customer_ 627540', 1) {'weight': 0.5773502691896258}
# ('claim_ 80', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 80', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 80', 3, 'customer_ 279422', 1) {'weight': 0.5773502691896258}
# ('claim_ 81', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 81', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 81', 3, 'customer_ 484200', 1) {'weight': 0.5773502691896258}
# ('claim_ 82', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 82', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 82', 3, 'customer_ 645258', 1) {'weight': 0.5773502691896258}
# ('claim_ 83', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 83', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 83', 3, 'customer_ 694662', 1) {'weight': 0.5773502691896258}
# ('claim_ 84', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 84', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 84', 3, 'customer_ 960680', 1) {'weight': 0.5773502691896258}
# ('claim_ 85', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 85', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 85', 3, 'customer_ 498140', 1) {'weight': 0.5773502691896258}
# ('claim_ 86', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 86', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 86', 3, 'customer_ 498875', 1) {'weight': 0.5773502691896258}
# ('claim_ 87', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 87', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 87', 3, 'customer_ 798177', 1) {'weight': 0.5773502691896258}
# ('claim_ 88', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 88', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 88', 3, 'customer_ 614763', 1) {'weight': 0.5773502691896258}
# ('claim_ 89', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 89', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 89', 3, 'customer_ 679370', 1) {'weight': 0.5773502691896258}
# ('claim_ 90', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 90', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 90', 3, 'customer_ 958857', 1) {'weight': 0.5773502691896258}
# ('claim_ 91', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 91', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 91', 3, 'customer_ 686816', 1) {'weight': 0.5773502691896258}
# ('claim_ 92', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 92', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 92', 3, 'customer_ 127754', 1) {'weight': 0.5773502691896258}
# ('claim_ 93', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 93', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 93', 3, 'customer_ 918629', 1) {'weight': 0.5773502691896258}
# ('claim_ 94', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 94', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 94', 3, 'customer_ 731450', 1) {'weight': 0.5773502691896258}
# ('claim_ 95', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 95', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 95', 3, 'customer_ 307447', 1) {'weight': 0.5773502691896258}
# ('claim_ 96', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 96', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 96', 3, 'customer_ 992145', 1) {'weight': 0.5773502691896258}
# ('claim_ 97', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 97', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 97', 3, 'customer_ 900628', 1) {'weight': 0.5773502691896258}
# ('claim_ 98', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 98', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 98', 3, 'customer_ 235220', 1) {'weight': 0.5773502691896258}
# ('claim_ 99', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 99', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 99', 3, 'customer_ 740019', 1) {'weight': 0.5773502691896258}
# ('claim_ 100', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 100', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 100', 3, 'customer_ 246882', 1) {'weight': 0.5773502691896258}
# ('claim_ 101', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 101', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 101', 3, 'customer_ 797613', 1) {'weight': 0.5773502691896258}
# ('claim_ 102', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 102', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 102', 3, 'customer_ 193442', 1) {'weight': 0.5773502691896258}
# ('claim_ 103', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 103', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 103', 3, 'customer_ 389238', 1) {'weight': 0.5773502691896258}
# ('claim_ 104', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 104', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 104', 3, 'customer_ 760179', 1) {'weight': 0.5773502691896258}
# ('claim_ 105', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 105', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 105', 3, 'customer_ 939905', 1) {'weight': 0.5773502691896258}
# ('claim_ 106', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 106', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 106', 3, 'customer_ 872814', 1) {'weight': 0.5773502691896258}
# ('claim_ 107', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 107', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 107', 3, 'customer_ 632627', 1) {'weight': 0.5773502691896258}
# ('claim_ 108', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 108', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 108', 3, 'customer_ 283414', 1) {'weight': 0.5773502691896258}
# ('claim_ 109', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 109', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 109', 3, 'customer_ 163161', 1) {'weight': 0.5773502691896258}
# ('claim_ 110', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 110', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 110', 3, 'customer_ 853360', 1) {'weight': 0.5773502691896258}
# ('claim_ 111', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 111', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 111', 3, 'customer_ 776860', 1) {'weight': 0.5773502691896258}
# ('claim_ 112', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 112', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 112', 3, 'customer_ 149367', 1) {'weight': 0.5773502691896258}
# ('claim_ 113', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 113', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 113', 3, 'customer_ 395269', 1) {'weight': 0.5773502691896258}
# ('claim_ 114', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 114', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 114', 3, 'customer_ 981123', 1) {'weight': 0.5773502691896258}
# ('claim_ 115', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 115', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 115', 3, 'customer_ 143626', 1) {'weight': 0.5773502691896258}
# ('claim_ 116', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 116', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 116', 3, 'customer_ 648397', 1) {'weight': 0.5773502691896258}
# ('claim_ 117', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 117', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 117', 3, 'customer_ 154982', 1) {'weight': 0.5773502691896258}
# ('claim_ 118', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 118', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 118', 3, 'customer_ 330591', 1) {'weight': 0.5773502691896258}
# ('claim_ 119', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 119', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 119', 3, 'customer_ 319232', 1) {'weight': 0.5773502691896258}
# ('claim_ 120', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 120', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 120', 3, 'customer_ 531640', 1) {'weight': 0.5773502691896258}
# ('claim_ 121', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 121', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 121', 3, 'customer_ 368050', 1) {'weight': 0.5773502691896258}
# ('claim_ 122', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 122', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 122', 3, 'customer_ 253791', 1) {'weight': 0.5773502691896258}
# ('claim_ 123', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 123', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 123', 3, 'customer_ 155724', 1) {'weight': 0.5773502691896258}
# ('claim_ 124', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 124', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 124', 3, 'customer_ 824540', 1) {'weight': 0.5773502691896258}
# ('claim_ 125', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 125', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 125', 3, 'customer_ 717392', 1) {'weight': 0.5773502691896258}
# ('claim_ 126', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 126', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 126', 3, 'customer_ 965768', 1) {'weight': 0.5773502691896258}
# ('claim_ 127', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 127', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 127', 3, 'customer_ 414779', 1) {'weight': 0.5773502691896258}
# ('claim_ 128', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 128', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 128', 3, 'customer_ 428230', 1) {'weight': 0.5773502691896258}
# ('claim_ 129', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 129', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 129', 3, 'customer_ 517240', 1) {'weight': 0.5773502691896258}
# ('claim_ 130', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 130', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 130', 3, 'customer_ 469874', 1) {'weight': 0.5773502691896258}
# ('claim_ 131', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 131', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 131', 3, 'customer_ 718428', 1) {'weight': 0.5773502691896258}
# ('claim_ 132', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 132', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 132', 3, 'customer_ 620215', 1) {'weight': 0.5773502691896258}
# ('claim_ 133', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 133', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 133', 3, 'customer_ 618659', 1) {'weight': 0.5773502691896258}
# ('claim_ 134', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 134', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 134', 3, 'customer_ 649082', 1) {'weight': 0.5773502691896258}
# ('claim_ 135', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 135', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 135', 3, 'customer_ 437573', 1) {'weight': 0.5773502691896258}
# ('claim_ 136', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 136', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 136', 3, 'customer_ 964657', 1) {'weight': 0.5773502691896258}
# ('claim_ 137', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 137', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 137', 3, 'customer_ 932502', 1) {'weight': 0.5773502691896258}
# ('claim_ 138', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 138', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 138', 3, 'customer_ 434507', 1) {'weight': 0.5773502691896258}
# ('claim_ 139', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 139', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 139', 3, 'customer_ 935277', 1) {'weight': 0.5773502691896258}
# ('claim_ 140', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 140', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 140', 3, 'customer_ 756054', 1) {'weight': 0.5773502691896258}
# ('claim_ 141', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 141', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 141', 3, 'customer_ 682387', 1) {'weight': 0.5773502691896258}
# ('claim_ 142', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 142', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 142', 3, 'customer_ 456604', 1) {'weight': 0.5773502691896258}
# ('claim_ 143', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 143', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 143', 3, 'customer_ 139872', 1) {'weight': 0.5773502691896258}
# ('claim_ 144', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 144', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 144', 3, 'customer_ 354105', 1) {'weight': 0.5773502691896258}
# ('claim_ 145', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 145', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 145', 3, 'customer_ 165485', 1) {'weight': 0.5773502691896258}
# ('claim_ 146', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 146', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 146', 3, 'customer_ 515050', 1) {'weight': 0.5773502691896258}
# ('claim_ 147', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 147', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 147', 3, 'customer_ 795686', 1) {'weight': 0.5773502691896258}
# ('claim_ 148', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 148', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 148', 3, 'customer_ 395983', 1) {'weight': 0.5773502691896258}
# ('claim_ 149', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 149', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 149', 3, 'customer_ 119513', 1) {'weight': 0.5773502691896258}
# ('claim_ 150', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 150', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 150', 3, 'customer_ 217938', 1) {'weight': 0.5773502691896258}
# ('claim_ 151', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 151', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 151', 3, 'customer_ 203914', 1) {'weight': 0.5773502691896258}
# ('claim_ 152', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 152', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 152', 3, 'customer_ 565157', 1) {'weight': 0.5773502691896258}
# ('claim_ 153', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 153', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 153', 3, 'customer_ 904191', 1) {'weight': 0.5773502691896258}
# ('claim_ 154', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 154', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 154', 3, 'customer_ 419510', 1) {'weight': 0.5773502691896258}
# ('claim_ 155', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 155', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 155', 3, 'customer_ 575000', 1) {'weight': 0.5773502691896258}
# ('claim_ 156', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 156', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 156', 3, 'customer_ 120485', 1) {'weight': 0.5773502691896258}
# ('claim_ 157', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 157', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 157', 3, 'customer_ 781181', 1) {'weight': 0.5773502691896258}
# ('claim_ 158', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 158', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 158', 3, 'customer_ 299796', 1) {'weight': 0.5773502691896258}
# ('claim_ 159', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 159', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 159', 3, 'customer_ 589749', 1) {'weight': 0.5773502691896258}
# ('claim_ 160', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 160', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 160', 3, 'customer_ 854021', 1) {'weight': 0.5773502691896258}
# ('claim_ 161', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 161', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 161', 3, 'customer_ 454086', 1) {'weight': 0.5773502691896258}
# ('claim_ 162', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 162', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 162', 3, 'customer_ 139484', 1) {'weight': 0.5773502691896258}
# ('claim_ 163', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 163', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 163', 3, 'customer_ 678849', 1) {'weight': 0.5773502691896258}
# ('claim_ 164', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 164', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 164', 3, 'customer_ 346940', 1) {'weight': 0.5773502691896258}
# ('claim_ 165', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 165', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 165', 3, 'customer_ 985436', 1) {'weight': 0.5773502691896258}
# ('claim_ 166', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 166', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 166', 3, 'customer_ 237418', 1) {'weight': 0.5773502691896258}
# ('claim_ 167', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 167', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 167', 3, 'customer_ 335780', 1) {'weight': 0.5773502691896258}
# ('claim_ 168', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 168', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 168', 3, 'customer_ 491392', 1) {'weight': 0.5773502691896258}
# ('claim_ 169', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 169', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 169', 3, 'customer_ 140880', 1) {'weight': 0.5773502691896258}
# ('claim_ 170', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 170', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 170', 3, 'customer_ 962591', 1) {'weight': 0.5773502691896258}
# ('claim_ 171', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 171', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 171', 3, 'customer_ 922565', 1) {'weight': 0.5773502691896258}
# ('claim_ 172', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 172', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 172', 3, 'customer_ 288580', 1) {'weight': 0.5773502691896258}
# ('claim_ 173', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 173', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 173', 3, 'customer_ 154280', 1) {'weight': 0.5773502691896258}
# ('claim_ 174', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 174', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 174', 3, 'customer_ 425973', 1) {'weight': 0.5773502691896258}
# ('claim_ 175', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 175', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 175', 3, 'customer_ 477177', 1) {'weight': 0.5773502691896258}
# ('claim_ 176', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 176', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 176', 3, 'customer_ 648509', 1) {'weight': 0.5773502691896258}
# ('claim_ 177', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 177', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 177', 3, 'customer_ 914815', 1) {'weight': 0.5773502691896258}
# ('claim_ 178', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 178', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 178', 3, 'customer_ 249048', 1) {'weight': 0.5773502691896258}
# ('claim_ 179', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 179', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 179', 3, 'customer_ 144323', 1) {'weight': 0.5773502691896258}
# ('claim_ 180', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 180', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 180', 3, 'customer_ 651861', 1) {'weight': 0.5773502691896258}
# ('claim_ 181', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 181', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 181', 3, 'customer_ 125324', 1) {'weight': 0.5773502691896258}
# ('claim_ 182', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 182', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 182', 3, 'customer_ 398102', 1) {'weight': 0.5773502691896258}
# ('claim_ 183', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 183', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 183', 3, 'customer_ 514065', 1) {'weight': 0.5773502691896258}
# ('claim_ 184', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 184', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 184', 3, 'customer_ 391652', 1) {'weight': 0.5773502691896258}
# ('claim_ 185', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 185', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 185', 3, 'customer_ 922167', 1) {'weight': 0.5773502691896258}
# ('claim_ 186', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 186', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 186', 3, 'customer_ 442795', 1) {'weight': 0.5773502691896258}
# ('claim_ 187', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 187', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 187', 3, 'customer_ 226330', 1) {'weight': 0.5773502691896258}
# ('claim_ 188', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 188', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 188', 3, 'customer_ 134430', 1) {'weight': 0.5773502691896258}
# ('claim_ 189', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 189', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 189', 3, 'customer_ 524230', 1) {'weight': 0.5773502691896258}
# ('claim_ 190', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 190', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 190', 3, 'customer_ 438817', 1) {'weight': 0.5773502691896258}
# ('claim_ 191', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 191', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 191', 3, 'customer_ 293794', 1) {'weight': 0.5773502691896258}
# ('claim_ 192', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 192', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 192', 3, 'customer_ 868283', 1) {'weight': 0.5773502691896258}
# ('claim_ 193', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 193', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 193', 3, 'customer_ 828890', 1) {'weight': 0.5773502691896258}
# ('claim_ 194', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 194', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 194', 3, 'customer_ 882920', 1) {'weight': 0.5773502691896258}
# ('claim_ 195', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 195', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 195', 3, 'customer_ 918777', 1) {'weight': 0.5773502691896258}
# ('claim_ 196', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 196', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 196', 3, 'customer_ 212580', 1) {'weight': 0.5773502691896258}
# ('claim_ 197', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 197', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 197', 3, 'customer_ 602410', 1) {'weight': 0.5773502691896258}
# ('claim_ 198', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 198', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 198', 3, 'customer_ 976971', 1) {'weight': 0.5773502691896258}
# ('claim_ 199', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 199', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 199', 3, 'customer_ 630226', 1) {'weight': 0.5773502691896258}
# ('claim_ 200', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 200', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 200', 3, 'customer_ 171254', 1) {'weight': 0.5773502691896258}
# ('claim_ 201', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 201', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 201', 3, 'customer_ 247116', 1) {'weight': 0.5773502691896258}
# ('claim_ 202', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 202', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 202', 3, 'customer_ 505969', 1) {'weight': 0.5773502691896258}
# ('claim_ 203', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 203', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 203', 3, 'customer_ 653864', 1) {'weight': 0.5773502691896258}
# ('claim_ 204', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 204', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 204', 3, 'customer_ 586367', 1) {'weight': 0.5773502691896258}
# ('claim_ 205', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 205', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 205', 3, 'customer_ 896890', 1) {'weight': 0.5773502691896258}
# ('claim_ 206', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 206', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 206', 3, 'customer_ 650026', 1) {'weight': 0.5773502691896258}
# ('claim_ 207', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 207', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 207', 3, 'customer_ 547744', 1) {'weight': 0.5773502691896258}
# ('claim_ 208', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 208', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 208', 3, 'customer_ 598124', 1) {'weight': 0.5773502691896258}
# ('claim_ 209', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 209', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 209', 3, 'customer_ 436126', 1) {'weight': 0.5773502691896258}
# ('claim_ 210', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 210', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 210', 3, 'customer_ 739447', 1) {'weight': 0.5773502691896258}
# ('claim_ 211', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 211', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 211', 3, 'customer_ 427484', 1) {'weight': 0.5773502691896258}
# ('claim_ 212', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 212', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 212', 3, 'customer_ 218684', 1) {'weight': 0.5773502691896258}
# ('claim_ 213', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 213', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 213', 3, 'customer_ 565564', 1) {'weight': 0.5773502691896258}
# ('claim_ 214', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 214', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 214', 3, 'customer_ 743163', 1) {'weight': 0.5773502691896258}
# ('claim_ 215', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 215', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 215', 3, 'customer_ 604614', 1) {'weight': 0.5773502691896258}
# ('claim_ 216', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 216', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 216', 3, 'customer_ 509928', 1) {'weight': 0.5773502691896258}
# ('claim_ 217', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 217', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 217', 3, 'customer_ 593390', 1) {'weight': 0.5773502691896258}
# ('claim_ 218', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 218', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 218', 3, 'customer_ 970607', 1) {'weight': 0.5773502691896258}
# ('claim_ 219', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 219', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 219', 3, 'customer_ 174701', 1) {'weight': 0.5773502691896258}
# ('claim_ 220', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 220', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 220', 3, 'customer_ 529398', 1) {'weight': 0.5773502691896258}
# ('claim_ 221', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 221', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 221', 3, 'customer_ 940942', 1) {'weight': 0.5773502691896258}
# ('claim_ 222', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 222', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 222', 3, 'customer_ 442677', 1) {'weight': 0.5773502691896258}
# ('claim_ 223', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 223', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 223', 3, 'customer_ 365364', 1) {'weight': 0.5773502691896258}
# ('claim_ 224', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 224', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 224', 3, 'customer_ 114839', 1) {'weight': 0.5773502691896258}
# ('claim_ 225', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 225', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 225', 3, 'customer_ 872734', 1) {'weight': 0.5773502691896258}
# ...
# ('claim_ 927', 3, 'customer_ 752504', 1) {'weight': 0.5773502691896258}
# ('claim_ 928', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 928', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 928', 3, 'customer_ 449263', 1) {'weight': 0.5773502691896258}
# ('claim_ 929', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 929', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 929', 3, 'customer_ 844007', 1) {'weight': 0.5773502691896258}
# ('claim_ 930', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 930', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 930', 3, 'customer_ 686522', 1) {'weight': 0.5773502691896258}
# ('claim_ 931', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 931', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 931', 3, 'customer_ 670142', 1) {'weight': 0.5773502691896258}
# ('claim_ 932', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 932', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 932', 3, 'customer_ 607687', 1) {'weight': 0.5773502691896258}
# ('claim_ 933', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 933', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 933', 3, 'customer_ 967713', 1) {'weight': 0.5773502691896258}
# ('claim_ 934', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 934', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 934', 3, 'customer_ 291902', 1) {'weight': 0.5773502691896258}
# ('claim_ 935', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 935', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 935', 3, 'customer_ 149839', 1) {'weight': 0.5773502691896258}
# ('claim_ 936', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 936', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 936', 3, 'customer_ 840225', 1) {'weight': 0.5773502691896258}
# ('claim_ 937', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 937', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 937', 3, 'customer_ 643226', 1) {'weight': 0.5773502691896258}
# ('claim_ 938', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 938', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 938', 3, 'customer_ 535879', 1) {'weight': 0.5773502691896258}
# ('claim_ 939', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 939', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 939', 3, 'customer_ 746630', 1) {'weight': 0.5773502691896258}
# ('claim_ 940', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 940', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 940', 3, 'customer_ 598308', 1) {'weight': 0.5773502691896258}
# ('claim_ 941', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 941', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 941', 3, 'customer_ 720356', 1) {'weight': 0.5773502691896258}
# ('claim_ 942', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 942', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 942', 3, 'customer_ 724752', 1) {'weight': 0.5773502691896258}
# ('claim_ 943', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 943', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 943', 3, 'customer_ 148498', 1) {'weight': 0.5773502691896258}
# ('claim_ 944', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 944', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 944', 3, 'customer_ 110122', 1) {'weight': 0.5773502691896258}
# ('claim_ 945', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 945', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 945', 3, 'customer_ 281388', 1) {'weight': 0.5773502691896258}
# ('claim_ 946', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 946', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 946', 3, 'customer_ 728600', 1) {'weight': 0.5773502691896258}
# ('claim_ 947', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 947', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 947', 3, 'customer_ 231548', 1) {'weight': 0.5773502691896258}
# ('claim_ 948', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 948', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 948', 3, 'customer_ 531160', 1) {'weight': 0.5773502691896258}
# ('claim_ 949', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 949', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 949', 3, 'customer_ 889003', 1) {'weight': 0.5773502691896258}
# ('claim_ 950', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 950', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 950', 3, 'customer_ 193213', 1) {'weight': 0.5773502691896258}
# ('claim_ 951', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 951', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 951', 3, 'customer_ 557218', 1) {'weight': 0.5773502691896258}
# ('claim_ 952', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 952', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 952', 3, 'customer_ 125591', 1) {'weight': 0.5773502691896258}
# ('claim_ 953', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 953', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 953', 3, 'customer_ 227244', 1) {'weight': 0.5773502691896258}
# ('claim_ 954', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 954', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 954', 3, 'customer_ 791425', 1) {'weight': 0.5773502691896258}
# ('claim_ 955', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 955', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 955', 3, 'customer_ 354455', 1) {'weight': 0.5773502691896258}
# ('claim_ 956', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 956', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 956', 3, 'customer_ 601042', 1) {'weight': 0.5773502691896258}
# ('claim_ 957', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 957', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 957', 3, 'customer_ 433663', 1) {'weight': 0.5773502691896258}
# ('claim_ 958', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 958', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 958', 3, 'customer_ 471938', 1) {'weight': 0.5773502691896258}
# ('claim_ 959', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 959', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 959', 3, 'customer_ 564654', 1) {'weight': 0.5773502691896258}
# ('claim_ 960', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 960', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 960', 3, 'customer_ 645723', 1) {'weight': 0.5773502691896258}
# ('claim_ 961', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 961', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 961', 3, 'customer_ 573572', 1) {'weight': 0.5773502691896258}
# ('claim_ 962', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 962', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 962', 3, 'customer_ 437960', 1) {'weight': 0.5773502691896258}
# ('claim_ 963', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 963', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 963', 3, 'customer_ 649800', 1) {'weight': 0.5773502691896258}
# ('claim_ 964', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 964', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 964', 3, 'customer_ 544225', 1) {'weight': 0.5773502691896258}
# ('claim_ 965', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 965', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 965', 3, 'customer_ 390256', 1) {'weight': 0.5773502691896258}
# ('claim_ 966', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 966', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 966', 3, 'customer_ 488597', 1) {'weight': 0.5773502691896258}
# ('claim_ 967', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 967', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 967', 3, 'customer_ 133889', 1) {'weight': 0.5773502691896258}
# ('claim_ 968', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 968', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 968', 3, 'customer_ 931901', 1) {'weight': 0.5773502691896258}
# ('claim_ 969', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 969', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 969', 3, 'customer_ 769475', 1) {'weight': 0.5773502691896258}
# ('claim_ 970', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 970', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 970', 3, 'customer_ 844062', 1) {'weight': 0.5773502691896258}
# ('claim_ 971', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 971', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 971', 3, 'customer_ 844129', 1) {'weight': 0.5773502691896258}
# ('claim_ 972', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 972', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 972', 3, 'customer_ 732169', 1) {'weight': 0.5773502691896258}
# ('claim_ 973', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 973', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 973', 3, 'customer_ 221854', 1) {'weight': 0.5773502691896258}
# ('claim_ 974', 3, 'workshop_ C', 79) {'weight': 0.06495698024616309}
# ('claim_ 974', 3, 'handler_ Harry', 80) {'weight': 0.06454972243679027}
# ('claim_ 974', 3, 'customer_ 776950', 1) {'weight': 0.5773502691896258}
# ('claim_ 975', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 975', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 975', 3, 'customer_ 291006', 1) {'weight': 0.5773502691896258}
# ('claim_ 976', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 976', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 976', 3, 'customer_ 845751', 1) {'weight': 0.5773502691896258}
# ('claim_ 977', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 977', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 977', 3, 'customer_ 889764', 1) {'weight': 0.5773502691896258}
# ('claim_ 978', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 978', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 978', 3, 'customer_ 929306', 1) {'weight': 0.5773502691896258}
# ('claim_ 979', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 979', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 979', 3, 'customer_ 515457', 1) {'weight': 0.5773502691896258}
# ('claim_ 980', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 980', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 980', 3, 'customer_ 556270', 1) {'weight': 0.5773502691896258}
# ('claim_ 981', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 981', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 981', 3, 'customer_ 908935', 1) {'weight': 0.5773502691896258}
# ('claim_ 982', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 982', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 982', 3, 'customer_ 525862', 1) {'weight': 0.5773502691896258}
# ('claim_ 983', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 983', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 983', 3, 'customer_ 490514', 1) {'weight': 0.5773502691896258}
# ('claim_ 984', 3, 'workshop_ B', 86) {'weight': 0.062257280636469035}
# ('claim_ 984', 3, 'handler_ George', 86) {'weight': 0.062257280636469035}
# ('claim_ 984', 3, 'customer_ 774895', 1) {'weight': 0.5773502691896258}
# ('claim_ 985', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 985', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 985', 3, 'customer_ 974522', 1) {'weight': 0.5773502691896258}
# ('claim_ 986', 3, 'workshop_ D', 100) {'weight': 0.05773502691896257}
# ('claim_ 986', 3, 'handler_ Ivan', 100) {'weight': 0.05773502691896257}
# ('claim_ 986', 3, 'customer_ 669809', 1) {'weight': 0.5773502691896258}
# ('claim_ 987', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 987', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 987', 3, 'customer_ 182953', 1) {'weight': 0.5773502691896258}
# ('claim_ 988', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 988', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 988', 3, 'customer_ 836349', 1) {'weight': 0.5773502691896258}
# ('claim_ 989', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 989', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 989', 3, 'customer_ 591269', 1) {'weight': 0.5773502691896258}
# ('claim_ 990', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 990', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 990', 3, 'customer_ 550127', 1) {'weight': 0.5773502691896258}
# ('claim_ 991', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 991', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 991', 3, 'customer_ 663190', 1) {'weight': 0.5773502691896258}
# ('claim_ 992', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 992', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 992', 3, 'customer_ 109392', 1) {'weight': 0.5773502691896258}
# ('claim_ 993', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 993', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 993', 3, 'customer_ 215278', 1) {'weight': 0.5773502691896258}
# ('claim_ 994', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 994', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 994', 3, 'customer_ 674570', 1) {'weight': 0.5773502691896258}
# ('claim_ 995', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 995', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 995', 3, 'customer_ 681486', 1) {'weight': 0.5773502691896258}
# ('claim_ 996', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 996', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 996', 3, 'customer_ 941851', 1) {'weight': 0.5773502691896258}
# ('claim_ 997', 3, 'workshop_ E', 95) {'weight': 0.05923488777590923}
# ('claim_ 997', 3, 'handler_ Jeff', 95) {'weight': 0.05923488777590923}
# ('claim_ 997', 3, 'customer_ 186934', 1) {'weight': 0.5773502691896258}
# ('claim_ 998', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 998', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 998', 3, 'customer_ 918516', 1) {'weight': 0.5773502691896258}
# ('claim_ 999', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 999', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 999', 3, 'customer_ 533940', 1) {'weight': 0.5773502691896258}
# ('claim_ 1000', 3, 'workshop_ A', 641) {'weight': 0.02280396458583536}
# ('claim_ 1000', 3, 'handler_ Frank', 640) {'weight': 0.02282177322938192}
# ('claim_ 1000', 3, 'customer_ 556080', 1) {'weight': 0.5773502691896258}
# ('workshop_ A', 641, 'claim_ 1234567', 3) {'weight': 0.02280396458583536}
# ('handler_ Harry', 80, 'claim_ 1234567', 3) {'weight': 0.06454972243679027}
# ('claim_ 1234567', 3, 'customer_ 773651', 1) {'weight': 0.5773502691896258}

# %%
G.edges[('claim_ 1', 'workshop_ A')]
# Out:
# {'weight': 0.02280396458583536}

# %%
print(bipartite.is_bipartite(G))
c = bipartite.color(G)
nodes = list(bipartite.color(G).keys())
# https://stackoverflow.com/questions/13517614/draw-different-color-for-nodes-in-networkx-based-on-their-node-value
color_map = {
    0: 'lightgreen',
    1: 'lightblue'
}
values = [color_map.get(value) for value in c.values()]
values
# Out:
# True
# ['lightblue',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightblue',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  'lightgreen',
#  ...]

# %%
G.edges
# Out:
# EdgeView([('claim_ 1', 'workshop_ A'), ('claim_ 1', 'handler_ Frank'), ('claim_ 1', 'customer_ 521585'), ('claim_ 2', 'workshop_ A'), ('claim_ 2', 'handler_ Frank'), ('claim_ 2', 'customer_ 342868'), ('claim_ 3', 'workshop_ A'), ('claim_ 3', 'handler_ Frank'), ('claim_ 3', 'customer_ 687698'), ('claim_ 4', 'workshop_ C'), ('claim_ 4', 'handler_ Harry'), ('claim_ 4', 'customer_ 227811'), ('claim_ 5', 'workshop_ C'), ('claim_ 5', 'handler_ Harry'), ('claim_ 5', 'customer_ 367455'), ('claim_ 6', 'workshop_ A'), ('claim_ 6', 'handler_ Frank'), ('claim_ 6', 'customer_ 104594'), ('claim_ 7', 'workshop_ A'), ('claim_ 7', 'handler_ Frank'), ('claim_ 7', 'customer_ 413978'), ('claim_ 8', 'workshop_ C'), ('claim_ 8', 'handler_ Harry'), ('claim_ 8', 'customer_ 429027'), ('claim_ 9', 'workshop_ E'), ('claim_ 9', 'handler_ Jeff'), ('claim_ 9', 'customer_ 485665'), ('claim_ 10', 'workshop_ D'), ('claim_ 10', 'handler_ Ivan'), ('claim_ 10', 'customer_ 636550'), ('claim_ 11', 'workshop_ A'), ('claim_ 11', 'handler_ Frank'), ('claim_ 11', 'customer_ 543610'), ('claim_ 12', 'workshop_ A'), ('claim_ 12', 'handler_ Frank'), ('claim_ 12', 'customer_ 214618'), ('claim_ 13', 'workshop_ B'), ('claim_ 13', 'handler_ George'), ('claim_ 13', 'customer_ 842643'), ('claim_ 14', 'workshop_ B'), ('claim_ 14', 'handler_ George'), ('claim_ 14', 'customer_ 626808'), ('claim_ 15', 'workshop_ A'), ('claim_ 15', 'handler_ Frank'), ('claim_ 15', 'customer_ 644081'), ('claim_ 16', 'workshop_ A'), ('claim_ 16', 'handler_ Frank'), ('claim_ 16', 'customer_ 892874'), ('claim_ 17', 'workshop_ A'), ('claim_ 17', 'handler_ Frank'), ('claim_ 17', 'customer_ 558938'), ('claim_ 18', 'workshop_ A'), ('claim_ 18', 'handler_ Frank'), ('claim_ 18', 'customer_ 275265'), ('claim_ 19', 'workshop_ C'), ('claim_ 19', 'handler_ Harry'), ('claim_ 19', 'customer_ 921202'), ('claim_ 20', 'workshop_ D'), ('claim_ 20', 'handler_ Ivan'), ('claim_ 20', 'customer_ 143972'), ('claim_ 21', 'workshop_ A'), ('claim_ 21', 'handler_ Frank'), ('claim_ 21', 'customer_ 183430'), ('claim_ 22', 'workshop_ A'), ('claim_ 22', 'handler_ Frank'), ('claim_ 22', 'customer_ 431876'), ('claim_ 23', 'workshop_ A'), ('claim_ 23', 'handler_ Frank'), ('claim_ 23', 'customer_ 285496'), ('claim_ 24', 'workshop_ A'), ('claim_ 24', 'handler_ Frank'), ('claim_ 24', 'customer_ 115399'), ('claim_ 25', 'workshop_ E'), ('claim_ 25', 'handler_ Jeff'), ('claim_ 25', 'customer_ 736882'), ('claim_ 26', 'workshop_ B'), ('claim_ 26', 'handler_ George'), ('claim_ 26', 'customer_ 699044'), ('claim_ 27', 'workshop_ A'), ('claim_ 27', 'handler_ Frank'), ('claim_ 27', 'customer_ 863236'), ('claim_ 28', 'workshop_ C'), ('claim_ 28', 'handler_ Harry'), ('claim_ 28', 'customer_ 608513'), ('claim_ 29', 'workshop_ A'), ('claim_ 29', 'handler_ Frank'), ('claim_ 29', 'customer_ 914088'), ('claim_ 30', 'workshop_ A'), ('claim_ 30', 'handler_ Frank'), ('claim_ 30', 'customer_ 596785'), ('claim_ 31', 'workshop_ D'), ('claim_ 31', 'handler_ Ivan'), ('claim_ 31', 'customer_ 908616'), ('claim_ 32', 'workshop_ A'), ('claim_ 32', 'handler_ Frank'), ('claim_ 32', 'customer_ 666333'), ('claim_ 33', 'workshop_ C'), ('claim_ 33', 'handler_ Harry'), ('claim_ 33', 'customer_ 336614'), ('claim_ 34', 'workshop_ A'), ('claim_ 34', 'handler_ Frank'), ('claim_ 34', 'customer_ 584859'), ('claim_ 35', 'workshop_ B'), ('claim_ 35', 'handler_ George'), ('claim_ 35', 'customer_ 990493'), ('claim_ 36', 'workshop_ B'), ('claim_ 36', 'handler_ George'), ('claim_ 36', 'customer_ 129872'), ('claim_ 37', 'workshop_ A'), ('claim_ 37', 'handler_ Frank'), ('claim_ 37', 'customer_ 200152'), ('claim_ 38', 'workshop_ E'), ('claim_ 38', 'handler_ Jeff'), ('claim_ 38', 'customer_ 933293'), ('claim_ 39', 'workshop_ A'), ('claim_ 39', 'handler_ Frank'), ('claim_ 39', 'customer_ 485664'), ('claim_ 40', 'workshop_ D'), ('claim_ 40', 'handler_ Ivan'), ('claim_ 40', 'customer_ 982871'), ('claim_ 41', 'workshop_ A'), ('claim_ 41', 'handler_ Frank'), ('claim_ 41', 'customer_ 206213'), ( ...

# %%
edgelist_df['Weight'] = edgelist_df.apply(lambda x: get_edgeweight(G, x), axis=1)
edgelist_df
# Out:
#                Parties      Claims    Weight
# 0     customer_ 521585    claim_ 1  0.577350
# 1          workshop_ A    claim_ 1  0.022804
# 2       handler_ Frank    claim_ 1  0.022822
# 3          workshop_ D   claim_ 10  0.057735
# 4        handler_ Ivan   claim_ 10  0.057735
# ...                ...         ...       ...
# 2995  customer_ 918516  claim_ 998  0.577350
# 2996       workshop_ A  claim_ 998  0.022804
# 2997       workshop_ A  claim_ 999  0.022804
# 2998  customer_ 533940  claim_ 999  0.577350
# 2999    handler_ Frank  claim_ 999  0.022822
#
# [3000 rows x 3 columns]

# %%
bn = Bipartite()
bn.set_edgelist(edgelist_df,  parties_col='Parties', claims_col='Claims')

parties_birank, claims_birank = bn.generate_birank(normalizer="BiRank", alpha=0.85, beta=1, prior=prior, max_iter=500, tol=1.0e-4, verbose=False)
claims_birank
# Out:
# No. of known prior fraudulent flags: 247.0 Length of prior_vector: 1000
#           Claims  birank_score
# 0       claim_ 1      0.416860
# 1      claim_ 10      0.150232
# 2     claim_ 100      0.193077
# 3    claim_ 1000      0.207558
# 4     claim_ 101      0.210185
# ..           ...           ...
# 995   claim_ 995      0.207558
# 996   claim_ 996      0.149816
# 997   claim_ 997      0.149816
# 998   claim_ 998      0.207558
# 999   claim_ 999      0.207558
#
# [1000 rows x 2 columns]

# %%
new_cols = {"Claims": "node", "Parties": "node"}
df = parties_birank.rename(columns=new_cols).append(claims_birank.rename(columns=new_cols)).reset_index(drop=True)
df
# Out:
#                   node  birank_score
# 0     customer_ 521585      0.240675
# 1          workshop_ A      3.834058
# 2       handler_ Frank      3.834058
# 3          workshop_ D      1.096966
# 4        handler_ Ivan      1.096966
# ...                ...           ...
# 2005        claim_ 995      0.207558
# 2006        claim_ 996      0.149816
# 2007        claim_ 997      0.149816
# 2008        claim_ 998      0.207558
# 2009        claim_ 999      0.207558
#
# [2010 rows x 2 columns]

# %%
df['n1_q1'] = df['node'].apply(lambda x: generate_n1_q1(G, df, x))

# %%
df['n1_med'] = df['node'].apply(lambda x: generate_n1_med(G, df, x))
df['n1_max'] = df['node'].apply(lambda x: generate_n1_max(G, df, x))
df['n2_q1'] = df['node'].apply(lambda x: generate_n2_q1(G, df, x))
df['n2_med'] = df['node'].apply(lambda x: generate_n2_med(G, df, x))
df['n2_max'] = df['node'].apply(lambda x: generate_n2_max(G, df, x))
df['n1_size'] = df['node'].apply(lambda x: generate_n1_size(G, df, x))
df['n2_size'] = df['node'].apply(lambda x: generate_n2_size(G, df, x))
df
# Out:
#                   node  birank_score     n1_q1    n1_med    n1_max     n2_q1  \
# 0     customer_ 521585      0.240675  0.416860  0.416860  0.416860  3.834058
# 1          workshop_ A      3.834058  0.207558  0.207558  0.416860  0.119834
# 2       handler_ Frank      3.834058  0.207558  0.207558  0.416860  0.119834
# 3          workshop_ D      1.096966  0.150232  0.150232  0.359535  0.086737
# 4        handler_ Ivan      1.096966  0.150232  0.150232  0.359535  0.086737
# ...                ...           ...       ...       ...       ...       ...
# 2005        claim_ 995      0.207558  1.976946  3.834058  3.834058  0.207558
# 2006        claim_ 996      0.149816  0.576362  1.066228  1.066228  0.149816
# 2007        claim_ 997      0.149816  0.576362  1.066228  1.066228  0.149816
# 2008        claim_ 998      0.207558  1.976946  3.834058  3.834058  0.207558
# 2009        claim_ 999      0.207558  1.976946  3.834058  3.834058  0.207558
#
#         n2_med    n2_max  n1_size  n2_size
# 0     3.834058  3.834058        1        2
# 1     0.119834  3.834058      641      643
# 2     0.119834  3.834058      640      641
# 3     0.086737  1.096966      100      101
# 4     0.086737  1.096966      100      101
# ...        ...       ...      ...      ...
# 2005  0.207558  0.416860        3      640
# 2006  0.149816  0.359119        3       94
# 2007  0.149816  0.359119        3       94
# 2008  0.207558  0.416860        3      640
# 2009  0.207558  0.416860        3      640
#
# [2010 rows x 10 columns]

# %%
df.to_csv('fraudscore.csv',index=False)
